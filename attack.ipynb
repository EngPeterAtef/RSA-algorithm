# %%
from main import *
import time as t
import matplotlib.pyplot as plt

# %% [markdown]
# ## Brute-Force Attack

# %%
# c is the ciphertext
# p is the plaintext
# start is the start of the range of the private key(= n/e)
# end is the end of the range of the private key(= n)
# this function performs the brute-force attack using the public key
# the idea of the attack:
# 1- try the values from [n/e: n] to find the private key this is the first loop and that because of our observations that 
# the private key has more probility to be greater than the public key
# 2- if the private key is not found in the first loop then try the values from [1: n/e] to find the private key this is the second loop
# 3- if the private key is not found in the second loop then the private key is not found and the attack fails
def attack(c: list[int], p: str, n: int,start:int,end:int)-> int :
    # the range of the key is from 1 to n
    for d in range(start, end):
        # if the plaintext is equal to the ciphertext
        x = decryption((d, n), c)
        if x.__contains__(p):#contains 34an al padding 
            # return the private key
            return d
    # if the private key is not found after the previous loop
    # then the private key is less than the public key
    for d in range(1,start):
        # if the plaintext is equal to the ciphertext
        x = decryption((d, n), c)
        if x.__contains__(p):#contains 34an al padding 
            # return the private key
            return d
    # if the private key is not found
    return -1

# %%
n = 200
msg = "hi"
enc_time_array = [0] * n
for i in range(20,20+n):
    # the public key and the private key
    public_key, private_key = keyGeneration(i) #min number of bits is 14 34an al encryption wel decryption y4t8lo
    print(f"public_key = {public_key} and private_key = {private_key}")
    # the ciphertext
    c = encryption(msg, public_key)
    start = t.time()
    d = attack(c, msg, public_key[1],public_key[1]//public_key[0],public_key[1])
    end = t.time()
    # for testing purpose
    if d == -1:
        print("not found")
        break
    enc_time_array[i-20] = end-start
plt.plot(range(20,20+n),enc_time_array, 'r')
plt.xlabel("number of bits")
plt.ylabel("time")
plt.title("time vs number of bits")
plt.show()
# Out:
# phi = 636086545920
# l = 40
# e = 794993
# public_key = (794993, 636088143877) and private_key = (37044566417, 636088143877)
# phi = 4145779446876
# l = 42
# e = 1923463
# public_key = (1923463, 4145783519117) and private_key = (2128760214283, 4145783519117)
# phi = 6920603842440
# l = 43
# e = 1996979
# public_key = (1996979, 6920609103887) and private_key = (6036053345939, 6920609103887)
# phi = 35669882490816
# l = 46
# e = 4474573
# public_key = (4474573, 35669894469509) and private_key = (8780323776325, 35669894469509)
# phi = 212737434997500
# l = 48
# e = 16688299
# public_key = (16688299, 212737464197501) and private_key = (55973329314199, 212737464197501)
# phi = 801074360474640
# l = 50
# e = 18320261
# public_key = (18320261, 801074417476387) and private_key = (315521991811181, 801074417476387)
# phi = 1416654459780672
# l = 51
# e = 33475129
# public_key = (33475129, 1416654535058051) and private_key = (198531920552137, 1416654535058051)
# phi = 8908216322533500
# l = 53
# ...

# %% [markdown]
# ## Fermat factoring algorithm Attack

# %%
n = 15
msg = "hi"
enc_time_array = [0] * n
for i in range(20,20+n):
    # the public key and the private key
    public_key, private_key = keyGeneration(i) #min number of bits is 14 34an al encryption wel decryption y4t8lo
    print(f"public_key = {public_key} and private_key = {private_key}")
    start = t.time()
    p,q = fermatFactoringAlgo(public_key[1])
    end = t.time()
    #for testing purpose
    if public_key[1] != p*q:
        print("not found")
        break
    enc_time_array[i-20] = end-start
plt.plot(range(20,20+n),enc_time_array, 'r')
plt.xlabel("number of bits")
plt.ylabel("time")
plt.title("time vs number of bits")
plt.show()
# Out:
# phi = 642201996756
# l = 40
# e = 723043
# public_key = (723043, 642203605097) and private_key = (89269650751, 642203605097)
# phi = 2010343288500
# l = 41
# e = 743069
# public_key = (743069, 2010346155161) and private_key = (241984438529, 2010346155161)
# phi = 12680234129640
# l = 44
# e = 2610449
# public_key = (2610449, 12680241278687) and private_key = (3632990841449, 12680241278687)
# phi = 33473747855968
# l = 45
# e = 3793549
# public_key = (3793549, 33473759614783) and private_key = (4687949525541, 33473759614783)
# phi = 189848375028720
# l = 48
# e = 9784493
# public_key = (9784493, 189848402836273) and private_key = (146462154851717, 189848402836273)
# phi = 513767380159740
# l = 49
# e = 13448159
# public_key = (13448159, 513767426764589) and private_key = (149709119983019, 513767426764589)
# phi = 3207174676056000
# l = 52
# e = 43188023
# public_key = (43188023, 3207174789671617) and private_key = (1893959504558087, 3207174789671617)
# phi = 13171200999111372
# ...

# %% [markdown]
# ## Analysis about different key sizes (number of bits of n) and how it affects the speed of encryption/decryption

# %%
n = 1000
msg = "hi"
enc_time_array = [0] * n
dec_time_array = [0] * n
for i in range(20,20+n):
    # the public key and the private key
    public_key, private_key = keyGeneration(i) #min number of bits is 14 34an al encryption wel decryption y4t8lo
    print(f"public_key = {public_key} and private_key = {private_key}")
    # the ciphertext
    start = t.time()
    c = encryption(msg, public_key)
    end = t.time()
    enc_time_array[i-20] = end-start
    start = t.time()
    p = decryption(private_key, c)
    end = t.time()
    dec_time_array[i-20] = end-start
    #for testing purpose
    if p != msg:
        print("Error")
        break
# Out:
# phi = 988362288000
# l = 40
# e = 993907
# public_key = (993907, 988364277559) and private_key = (561832122043, 988364277559)
# phi = 2581992108864
# l = 42
# e = 1892497
# public_key = (1892497, 2581995324431) and private_key = (2371486767793, 2581995324431)
# phi = 11653292461600
# l = 44
# e = 4102807
# public_key = (4102807, 11653299416173) and private_key = (6650548337543, 11653299416173)
# phi = 50187731708008
# l = 46
# e = 4436321
# public_key = (4436321, 50187745932763) and private_key = (46267036654025, 50187745932763)
# phi = 154006262802624
# l = 48
# e = 12582893
# public_key = (12582893, 154006288447061) and private_key = (98099678116709, 154006288447061)
# phi = 876696052813056
# l = 50
# e = 23621639
# public_key = (23621639, 876696112220087) and private_key = (332391387276983, 876696112220087)
# phi = 2955936349117336
# l = 52
# e = 57031993
# public_key = (57031993, 2955936458417707) and private_key = (38972163833169, 2955936458417707)
# phi = 8508147747480552
# ...

# %%
plt.plot(range(20,20+n),enc_time_array, 'r')
plt.xlabel("number of bits")
plt.ylabel("time")
plt.title("Encryption Time vs number of bits")
plt.show()

# %%
plt.plot(range(20,20+n),dec_time_array, 'r')
plt.xlabel("number of bits")
plt.ylabel("time")
plt.title("Decryption Time vs number of bits")
plt.show()
